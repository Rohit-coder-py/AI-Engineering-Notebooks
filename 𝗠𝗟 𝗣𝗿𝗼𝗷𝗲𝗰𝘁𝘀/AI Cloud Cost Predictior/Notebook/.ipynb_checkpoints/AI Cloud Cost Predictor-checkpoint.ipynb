# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r"C:\Users\shobh\Downloads\AI and DATA SCIENCE\𝗠𝗟 𝗣𝗿𝗼𝗷𝗲𝗰𝘁𝘀\AI Cloud Cost Predictior\data\anonymized_costs.csv")


df = pd.DataFrame(data)
pd.set_option('display.max_rows', None)

# %%
df.sample(3)
# Out:
#                                       InvoiceSectionName        Date  \
# 60595  bc05844fb9454a82a5380ad11fceccc59227e495d31ab1...  02/27/2023
# 63082  bc05844fb9454a82a5380ad11fceccc59227e495d31ab1...  02/07/2023
# 9844   bc05844fb9454a82a5380ad11fceccc59227e495d31ab1...  03/09/2023
#
#                     MeterCategory  CostInBillingCurrency MeterSubCategory  \
# 60595  Advanced Threat Protection               0.238556          Storage
# 63082               Load Balancer               0.165736         Standard
# 9844                    Bandwidth               0.000005     Inter-Region
#
#                                            MeterName  \
# 60595                                  Standard Node
# 63082  Standard Included LB Rules and Outbound Rules
# 9844               Intra Continent Data Transfer Out
#
#                                         SubscriptionName  \
# 60595  95e7dd23f5eed773783fc94e66ed6198d77b9b7c41c51c...
# ...

# %%
df['MeterCategory'].sum()
# Out:
# 'Azure App ServiceLoad BalancerStorageLoad BalancerStorageStorageBandwidthStorageStorageStorageAzure App ServiceAzure Front Door ServiceStorageStorageStorageStorageStorageBandwidthLoad BalancerStorageVirtual MachinesStorageLoad BalancerVirtual NetworkBandwidthVirtual NetworkBandwidthStorageStorageStorageBandwidthStorageBandwidthStorageLogic AppsStorageAzure App ServiceBandwidthStorageStorageStorageBandwidthVirtual MachinesStorageVirtual NetworkLoad BalancerStorageVirtual NetworkStorageBandwidthStorageStorageStorageBackupStorageStorageAzure DNSStorageLoad BalancerVirtual NetworkStorageStorageStorageVirtual NetworkStorageStorageStorageStorageLoad BalancerStorageStorageStorageStorageVirtual MachinesStorageBandwidthVirtual NetworkBandwidthStorageStorageStorageAzure DNSStorageStorageStorageVirtual NetworkStorageStorageStorageStorageStorageStorageLoad BalancerStorageAzure Front Door ServiceAzure Front Door ServiceVirtual NetworkStorageStorageStorageStorageStorageStorageStorageAzure Monitor
# ...
