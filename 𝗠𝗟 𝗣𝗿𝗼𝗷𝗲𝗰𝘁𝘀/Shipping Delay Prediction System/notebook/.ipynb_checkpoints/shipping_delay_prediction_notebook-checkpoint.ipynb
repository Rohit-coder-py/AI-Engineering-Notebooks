# %% [markdown]
# <div style="background:white; border:3px solid #4F46E5; border-radius:18px; padding:30px;">
#
# <h1 align="center" style="font-family:Georgia,serif; color:#4F46E5;">
# Project Description
# </h1>
#
# <div style="background:#EEF2FF; border-left:6px solid #4F46E5; padding:20px; border-radius:11px;">
#
# <p style="font-family:'Trebuchet MS',sans-serif; font-size:18px; color:#222;">
# Every day, logistics companies such as <b>Amazon</b>, <b>Flipkart</b>, <b>DHL</b>, <b>FedEx</b>, and <b>Blue Dart</b> process thousands of shipments. While many packages arrive on schedule, some are delayed due to factors like weather, traffic, shipping method, warehouse workload, product characteristics, or operational inefficiencies.
# </p>
#
# </div>
#
# <br>
#
# <h2 style="font-family:'Palatino Linotype',serif; color:#DC2626;">
# Challenges Caused by Delivery Delays
# </h2>
#
# <div style="background:#FEF2F2; border-left:6px solid #EF4444; padding:20px; border-radius:10px;">
#
# <p style="font-family:'Book Antiqua',serif; font-size:18px;">• Poor customer satisfaction</p>
#
# <p style="font-family:'Book Antiqua',serif; font-size:18px;">• Increased operational costs</p>
#
# <p style="font-family:'Book Antiqua',serif; font-size:18px;">• Supply chain disruptions</p>
#
# <p style="font-family:'Book Antiqua',serif; font-size:18px; margin-bottom:0;">• Negative reviews and loss of customer trust</p>
#
# </div>
#
# <br>
#
# <div style="background:#FFF7ED; border-left:6px solid #F97316; padding:20px; border-radius:10px;">
#
# <p style="font-family:'Segoe UI',sans-serif; font-size:18px; color:#222;">
# To reduce these problems, logistics companies need a way to predict potential delivery delays <b>before a shipment leaves the warehouse.</b>
# </p>
#
# </div>
#
# <br>
#
# <div style="background:#ECFDF5; border-left:6px solid #10B981; padding:20px; border-radius:10px;">
#
# <p style="font-family:'Trebuchet MS',sans-serif; font-size:18px; color:#222;">
# This project develops a <b>Machine Learning-based Shipping Delay Prediction System</b> that analyzes shipment information and predicts whether a package is likely to be <b>delivered on time</b> or <b>delayed</b>.
# </p>
#
# </div>
#
# <br>
#
# <div style="background:#EFF6FF; border-left:6px solid #2563EB; padding:20px; border-radius:10px;">
#
# <p style="font-family:'Book Antiqua',serif; font-size:18px; color:#222;">
# The prediction enables logistics teams to make proactive decisions, such as selecting a faster shipping method, optimizing delivery routes, allocating experienced drivers, and informing customers about possible delays in advance.
# </p>
#
# </div>
#
# <br>
#
# <div style="background:#F5F3FF; border-left:6px solid #8B5CF6; padding:20px; border-radius:10px;">
#
# <p style="font-family:'Palatino Linotype',serif; font-size:18px; color:#222; margin:0;">
# Beyond prediction, the project also includes <b>logistics analytics</b> to identify the key factors contributing to delivery delays, helping businesses improve overall delivery performance, reduce operational inefficiencies, and enhance customer satisfaction.
# </p>
#
# </div>
#
# </div>

# %% [markdown]
# <div style="background:white; border:3px solid #7C3AED; border-radius:18px; padding:30px;">
#
# <h1 align="center" style="font-family:Georgia,serif; color:#7C3AED;">
# Business Problem
# </h1>
#
# <div style="background:#F5F3FF; border-left:6px solid #7C3AED; padding:20px; border-radius:10px;">
#
# <p style="font-family:'Trebuchet MS',sans-serif; font-size:18px; color:#222; margin:0;">
# A logistics company wants to identify shipments that are at a <b>high risk of being delayed</b> before dispatch.
# </p>
#
# </div>
#
# <br>
#
# <h2 style="font-family:'Palatino Linotype',serif; color:#059669;">
# Business Benefits
# </h2>
#
# <div style="background:#ECFDF5; border-left:6px solid #10B981; padding:20px; border-radius:10px;">
#
# <p style="font-family:'Book Antiqua',serif; font-size:18px;">✔ Improve delivery planning</p>
#
# <p style="font-family:'Book Antiqua',serif; font-size:18px;">✔ Reduce late deliveries</p>
#
# <p style="font-family:'Book Antiqua',serif; font-size:18px;">✔ Optimize shipping operations</p>
#
# <p style="font-family:'Book Antiqua',serif; font-size:18px;">✔ Increase customer satisfaction</p>
#
# <p style="font-family:'Book Antiqua',serif; font-size:18px;">✔ Reduce operational costs</p>
#
# <p style="font-family:'Book Antiqua',serif; font-size:18px; margin-bottom:0;">✔ Make better business decisions using data</p>
#
# </div>
#
# </div>

# %% [markdown]
# <div style="background:white; border:3px solid #2563EB; border-radius:18px; padding:30px;">
#
# <h1 align="center" style="font-family:Georgia,serif; color:#2563EB;">
# Problem Statement
# </h1>
#
# <div style="background:#EFF6FF; border-left:6px solid #2563EB; padding:20px; border-radius:10px;">
#
# <p style="font-family:'Trebuchet MS',sans-serif; font-size:18px; color:#222; margin:0;">
# A logistics company wants to predict whether a shipment will be <b>delivered on time</b> or <b>delayed</b> before dispatching it.
# </p>
#
# </div>
#
# <br>
#
# <h2 style="font-family:'Palatino Linotype',serif; color:#059669;">
# Why is this important?
# </h2>
#
# <div style="background:#ECFDF5; border-left:6px solid #10B981; padding:20px; border-radius:10px;">
#
# <p style="font-family:'Book Antiqua',serif; font-size:18px;">✔ Inform customers proactively</p>
#
# <p style="font-family:'Book Antiqua',serif; font-size:18px;">✔ Choose a different shipping route</p>
#
# <p style="font-family:'Book Antiqua',serif; font-size:18px;">✔ Prioritize urgent shipments</p>
#
# <p style="font-family:'Book Antiqua',serif; font-size:18px;">✔ Reduce operational costs</p>
#
# <p style="font-family:'Book Antiqua',serif; font-size:18px; margin-bottom:0;">✔ Improve customer satisfaction</p>
#
# </div>
#
# </div>

# %% [markdown]
# Business Understanding
#         ↓
# Data Collection
#         ↓
# Dataset Understanding
#         ↓
# Data Cleaning
#         ↓
# Handle Outliers (if required)
#         ↓
# Exploratory Data Analysis (EDA)
#         ↓
# Feature Engineering
#         ↓
# Encoding
#         ↓
# Define X and y
#         ↓
# Train-Test Split
#         ↓
# Feature Scaling (if required)
#         ↓
# (Optional) PCA / Feature Selection
#         ↓
# Train Multiple Models
#         ↓
# Cross Validation
#         ↓
# Hyperparameter Tuning
#         ↓
# Final Model Selection
#         ↓
# Evaluation on Test Set
#         ↓
# Save Model
#         ↓
# Deployment (Streamlit)
#         ↓
# GitHub + README

# %%
## lets start now

# %%
import os
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#image save paths for all graphs

save_path = r"C:\Users\shobh\Downloads\AI and DATA SCIENCE\𝗠𝗟 𝗣𝗿𝗼𝗷𝗲𝗰𝘁𝘀\Shipping Delay Prediction System\graphs"

os.makedirs(save_path, exist_ok=True)

# %%
data = pd.read_csv(r"C:\Users\shobh\Downloads\AI and DATA SCIENCE\𝗠𝗟 𝗣𝗿𝗼𝗷𝗲𝗰𝘁𝘀\Shipping Delay Prediction System\data\raw_data.csv")


df = pd.DataFrame(data)

# %% [markdown]
# <p align="center" style="font-size:20px;">
#     <strong><span style="color:#2563EB;">Exploratory Data Analysis (EDA) Starts Here</span></strong>
# </p>
#
# <hr>

# %%
df.info()

# %%
df.sample(12)

# %%
df['Warehouse_block'].value_counts()

# %%
#lets check if any null values

df.isnull().sum()

# %%
# lets check if any dupliacted row

df.duplicated().sum()

# %% [markdown]
# <p style="font-size:22px; font-weight:bold;">
#     <span style="color:#2563EB;">Observation :</span>
# </p>
#
# <p>
# No <strong style="color:#DC2626;">missing values</strong> or <strong style="color:#DC2626;">missing rows</strong> were found in the dataset. The dataset is <strong style="color:#16A34A;">complete</strong>, <strong style="color:#16A34A;">consistent</strong>, and ready for <strong>Exploratory Data Analysis (EDA)</strong> and <strong>Machine Learning</strong> without any preprocessing related to missing data.
# </p>

# %%
# boxplots for outliers detection

import os
import matplotlib.pyplot as plt
import seaborn as sns

save_path = r"C:\Users\shobh\Downloads\AI and DATA SCIENCE\𝗠𝗟 𝗣𝗿𝗼𝗷𝗲𝗰𝘁𝘀\Shipping Delay Prediction System\graphs"

# Boxplots for Outlier Detection

numerical_cols = [
    "Customer_care_calls",
    "Customer_rating",
    "Cost_of_the_Product",
    "Prior_purchases",
    "Discount_offered",
    "Weight_in_gms"
]

for col in numerical_cols:

    plt.figure(figsize=(8, 4))

    sns.boxplot(
        x=df[col],
        color="skyblue"
    )

    plt.title(f"Boxplot of {col}", fontsize=16, fontweight="bold", pad=15)

    plt.xlabel(col, fontsize=12)

    plt.grid(axis="x", linestyle="--", alpha=0.5)

    plt.tight_layout()

    plt.savefig(
        os.path.join(save_path, f"{col}_Boxplot.png"),
        dpi=300, bbox_inches="tight")

    plt.show()

# %% [markdown]
# <p style="font-size:22px;"><strong><span style="color:#2563EB;">Observation</span></strong></p>
#
# <ul>
#     <li>The dataset contains <strong style="color:#DC2626;">several outliers</strong></li>
#     <li>These outliers <strong style="color:#16A34A;">will not be handled</strong> because they occur in features such as <strong>Discount_offered</strong>, where extreme values are <strong>normal and expected</strong>.</li>
# </ul>

# %%
df.info()

df_cleaned = df.copy()

# %%
# Saving the cleaned dataset as a csv file

save_path = r"C:\Users\shobh\Downloads\AI and DATA SCIENCE\𝗠𝗟 𝗣𝗿𝗼𝗷𝗲𝗰𝘁𝘀\Shipping Delay Prediction System\data\cleaned.csv"

df_cleaned.to_csv(save_path, index=False)

# %%
df.columns

# %%
df.sample(6)

# %%
df['Warehouse_block'].nunique()

# %%
df['Mode_of_Shipment'].nunique()

# %%
df.nunique()

# %% [markdown]
# <p align="center" style="font-size:20px;">
#     <strong><span style="color:#2563EB;">Feature Engineering Starts Here</span></strong>
# </p>
#
# <hr>

# %% [markdown]
# <p style="font-size:22px;">
# <strong><span style="color:#2563EB;">Observation</span></strong>
# </p>
#
# <ul>
#     <li>Now we have to select <mark><strong>features (X)</strong></mark> and <mark><strong>target variable (y)</strong></mark> for our model.</li>
#     <li>After observing all the columns in the dataset before finalising we need to filter out some columns that can be meaningless for our dataset.</li>
# </ul>
#
# <p style="font-size:20px;">
# <strong><span style="color:#7C3AED;">Columns : 12</span></strong>
# </p>
#
# <p><strong><span style="color:#DC2626;">1. ID</span></strong> - it is just IDs of the orders which will not be good for our training data so we will <mark>drop it</mark>.</p>
#
# <p><strong><span style="color:#16A34A;">2. Warehouse_block</span></strong> - it represents only <mark><strong>5 unique values</strong></mark> and we will keep this column.</p>
#
# <p><strong><span style="color:#16A34A;">3. Mode_of_Shipment</span></strong> - it will play a integral role for our model to predict shipping delay. It represents the mode of shipment and have <mark><strong>3 unique values</strong></mark>.</p>
#
# <p><strong><span style="color:#16A34A;">4. Customer_care_calls</span></strong> - it represents the number of customer care calls made by the customer and have <mark><strong>6 unique values</strong></mark>. This feature can have a relationship with shipping delay so we will keep this column.</p>
#
# <p><strong><span style="color:#DC2626;">5. Customer_rating</span></strong> - it represents the customer rating and have <mark><strong>5 unique values</strong></mark>. Since the rating is generally given after the delivery process it can introduce <mark><strong>data leakage</strong></mark> so we will drop this column.</p>
#
# <p><strong><span style="color:#16A34A;">6. Cost_of_the_Product</span></strong> - it represents the cost of the product and have <mark><strong>215 unique values</strong></mark>. Product cost may affect the shipping priority so we will keep this column.</p>
#
# <p><strong><span style="color:#16A34A;">7. Prior_purchases</span></strong> - it represents the number of previous purchases made by the customer and have <mark><strong>8 unique values</strong></mark>. This feature can help our model identify customer purchasing behaviour so we will keep this column.</p>
#
# <p><strong><span style="color:#16A34A;">8. Product_importance</span></strong> - it represents the importance level of the product and have <mark><strong>3 unique values</strong></mark>. Product importance can influence shipping priority so we will keep this column.</p>
#
# <p><strong><span style="color:#DC2626;">9. Gender</span></strong> - it represents the gender of the customer and have <mark><strong>2 unique values</strong></mark>. This feature has no meaningful relationship with shipping delay so we will drop this column.</p>
#
# <p><strong><span style="color:#16A34A;">10. Discount_offered</span></strong> - it represents the discount offered on the product and have <mark><strong>65 unique values</strong></mark>. This feature can influence shipping behaviour so we will keep this column.</p>
#
# <p><strong><span style="color:#16A34A;">11. Weight_in_gms</span></strong> - it represents the weight of the product in grams and have <mark><strong>4034 unique values</strong></mark>. Product weight can directly affect shipping time so we will keep this column.</p>
#
# <p><strong><span style="color:#2563EB;">12. Reached.on.Time_Y.N</span></strong> - it represents whether the shipment reached on time or not and have <mark><strong>2 unique values</strong></mark>. This is our <mark><strong>target variable (y)</strong></mark>.</p>

# %%
#encoding

from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

df['Warehouse_block'] = LabelEncoder().fit_transform(df['Warehouse_block'])

df['Mode_of_Shipment'] = LabelEncoder().fit_transform(df['Mode_of_Shipment'])
df['Product_importance'] = LabelEncoder().fit_transform(df['Product_importance'])

# %%
#X and y

X = df.drop(columns=["ID", "Gender", "Reached.on.Time_Y.N"])

y = df["Reached.on.Time_Y.N"]

# %%
df_encoded = df.copy()

# %%
# Saving the encoded dataset as a csv file

save_path = r"C:\Users\shobh\Downloads\AI and DATA SCIENCE\𝗠𝗟 𝗣𝗿𝗼𝗷𝗲𝗰𝘁𝘀\Shipping Delay Prediction System\data\encoded.csv"

df_encoded.to_csv(save_path, index=False)

# %%
#after ncoding next step step is train_test_split


from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.20, random_state=42)

X_train.head()

# %%
#now encodind and train test split done now we will perform feature scaling


from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)

X_test_scaled = scaler.fit(X_test)

# %% [markdown]
# <p style="font-size:22px;">
#     <strong><span style="color:#2563EB;">Observation</span></strong>
# </p>
#
# <p>
# <strong><span style="color:#16A34A;">Data Pre-processing</span></strong> is now <mark><strong>completed</strong></mark> and now let's <strong><span style="color:#7C3AED;">train models</span></strong>. We will train <strong><span style="color:#DC2626;">Classification Models</span></strong> hence our <strong><span style="color:#2563EB;">final end goal</span></strong> is to predict whether <mark><strong>Yes</strong></mark> or <mark><strong>No</strong></mark>.
# </p>
#
# <p>
# <strong><span style="color:#16A34A;"> lets start</span></strong>
# </p>

# %% [markdown]
# <div style="background:white; border:3px solid #4F46E5; border-radius:20px; padding:30px;">
#
# <h1 align="center" style="font-family:Georgia,serif; color:#4F46E5;">
# 📋 Machine Learning Models & Scaling Requirement
# </h1>
#
# <br>
#
# <table style="width:100%; border-collapse:collapse; font-family:'Segoe UI',sans-serif;">
#
# <tr style="background:#EDE9FE;">
# <th style="border:1px solid #CBD5E1; padding:12px;">Model</th>
# <th style="border:1px solid #CBD5E1; padding:12px;">Category</th>
# <th style="border:1px solid #CBD5E1; padding:12px;">Scaling Required?</th>
# <th style="border:1px solid #CBD5E1; padding:12px;">Use</th>
# </tr>
#
# <tr>
# <td style="border:1px solid #CBD5E1; padding:12px;"><b>Logistic Regression</b></td>
# <td style="border:1px solid #CBD5E1; padding:12px;">Classification</td>
# <td style="border:1px solid #CBD5E1; padding:12px; color:#059669;"><b>✅ Yes</b></td>
# <td style="border:1px solid #CBD5E1; padding:12px;"><code>X_train_scaled</code>, <code>X_test_scaled</code></td>
# </tr>
#
# <tr>
# <td style="border:1px solid #CBD5E1; padding:12px;"><b>KNeighborsClassifier (KNN)</b></td>
# <td style="border:1px solid #CBD5E1; padding:12px;">Classification</td>
# <td style="border:1px solid #CBD5E1; padding:12px; color:#059669;"><b>✅ Yes</b></td>
# <td style="border:1px solid #CBD5E1; padding:12px;"><code>X_train_scaled</code>, <code>X_test_scaled</code></td>
# </tr>
#
# <tr>
# <td style="border:1px solid #CBD5E1; padding:12px;"><b>SVC (Support Vector Machine)</b></td>
# <td style="border:1px solid #CBD5E1; padding:12px;">Classification</td>
# <td style="border:1px solid #CBD5E1; padding:12px; color:#059669;"><b>✅ Yes</b></td>
# <td style="border:1px solid #CBD5E1; padding:12px;"><code>X_train_scaled</code>, <code>X_test_scaled</code></td>
# </tr>
#
# <tr>
# <td style="border:1px solid #CBD5E1; padding:12px;"><b>GaussianNB</b></td>
# <td style="border:1px solid #CBD5E1; padding:12px;">Classification</td>
# <td style="border:1px solid #CBD5E1; padding:12px; color:#DC2626;"><b>❌ No</b></td>
# <td style="border:1px solid #CBD5E1; padding:12px;"><code>X_train</code>, <code>X_test</code></td>
# </tr>
#
# <tr>
# <td style="border:1px solid #CBD5E1; padding:12px;"><b>DecisionTreeClassifier</b></td>
# <td style="border:1px solid #CBD5E1; padding:12px;">Classification</td>
# <td style="border:1px solid #CBD5E1; padding:12px; color:#DC2626;"><b>❌ No</b></td>
# <td style="border:1px solid #CBD5E1; padding:12px;"><code>X_train</code>, <code>X_test</code></td>
# </tr>
#
# <tr>
# <td style="border:1px solid #CBD5E1; padding:12px;"><b>RandomForestClassifier</b></td>
# <td style="border:1px solid #CBD5E1; padding:12px;">Ensemble Learning</td>
# <td style="border:1px solid #CBD5E1; padding:12px; color:#DC2626;"><b>❌ No</b></td>
# <td style="border:1px solid #CBD5E1; padding:12px;"><code>X_train</code>, <code>X_test</code></td>
# </tr>
#
# <tr>
# <td style="border:1px solid #CBD5E1; padding:12px;"><b>AdaBoostClassifier</b></td>
# <td style="border:1px solid #CBD5E1; padding:12px;">Ensemble Learning</td>
# <td style="border:1px solid #CBD5E1; padding:12px; color:#DC2626;"><b>❌ No</b></td>
# <td style="border:1px solid #CBD5E1; padding:12px;"><code>X_train</code>, <code>X_test</code></td>
# </tr>
#
# <tr>
# <td style="border:1px solid #CBD5E1; padding:12px;"><b>GradientBoostingClassifier</b></td>
# <td style="border:1px solid #CBD5E1; padding:12px;">Ensemble Learning</td>
# <td style="border:1px solid #CBD5E1; padding:12px; color:#DC2626;"><b>❌ No</b></td>
# <td style="border:1px solid #CBD5E1; padding:12px;"><code>X_train</code>, <code>X_test</code></td>
# </tr>
#
# <tr>
# <td style="border:1px solid #CBD5E1; padding:12px;"><b>XGBClassifier</b></td>
# <td style="border:1px solid #CBD5E1; padding:12px;">Ensemble Learning</td>
# <td style="border:1px solid #CBD5E1; padding:12px; color:#DC2626;"><b>❌ No</b></td>
# <td style="border:1px solid #CBD5E1; padding:12px;"><code>X_train</code>, <code>X_test</code></td>
# </tr>
#
# <tr>
# <td style="border:1px solid #CBD5E1; padding:12px;"><b>StackingClassifier</b></td>
# <td style="border:1px solid #CBD5E1; padding:12px;">Ensemble Learning</td>
# <td style="border:1px solid #CBD5E1; padding:12px; color:#D97706;"><b>⚠️ Depends on the base models</b></td>
# <td style="border:1px solid #CBD5E1; padding:12px;">Usually same preprocessing as the base models</td>
# </tr>
# <tr>
# <td style="border:1px solid #CBD5E1; padding:12px;"><b>KMeans</b></td>
# <td style="border:1px solid #CBD5E1; padding:12px;">Clustering</td>
# <td style="border:1px solid #CBD5E1; padding:12px; color:#059669;"><b>✅ Yes</b></td>
# <td style="border:1px solid #CBD5E1; padding:12px;"><code>X_scaled</code></td>
# </tr>
#
# <tr>
# <td style="border:1px solid #CBD5E1; padding:12px;"><b>DBSCAN</b></td>
# <td style="border:1px solid #CBD5E1; padding:12px;">Clustering</td>
# <td style="border:1px solid #CBD5E1; padding:12px; color:#059669;"><b>✅ Yes</b></td>
# <td style="border:1px solid #CBD5E1; padding:12px;"><code>X_scaled</code></td>
# </tr>
#
# </table>
#
#
# </div>

# %%
# now first we will start with models that usually  need scaling 

# 1. Logistic Regression
# 2. k-nearest neighbors
# 3. SVM


# we will train each model note their evaluation metrics and compare all models together at last and perform model tuning on best 3 models

# %%
#logistic regression 


from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

lr_model = LinearRegression()


lr_model.fit(X_train_scaled,y_train)

y_pred_lr = lr_model.predict(X_test)
print("Accuracy :", accuracy_score(y_test, y_pred_lr))
print("Precision:", precision_score(y_test, y_pred_lr))
print("Recall   :", recall_score(y_test, y_pred_lr))
print("F1 Score :", f1_score(y_test, y_pred_lr))
