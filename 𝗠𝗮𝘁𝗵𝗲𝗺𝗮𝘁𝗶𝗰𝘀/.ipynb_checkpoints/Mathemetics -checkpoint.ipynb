# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import matplotlib.pyplot as plt
import seaborn as sns

data = [2,2,3,4,4,4,5]

sns.stripplot(x=data)

plt.title("Dot Plot")
plt.show()
