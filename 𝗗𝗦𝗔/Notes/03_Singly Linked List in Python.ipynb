# %% [markdown]
# <h2 style="font-size:32px; color:#1E3A8A; border-bottom:2px solid #DBEAFE; padding-bottom:7px; font-family:Georgia, serif;">
#     <strong>Linked List</strong>
# </h2>
#
# <h3 style="font-size:24px; color:#374151;">
#     <strong>Definition</strong>
# </h3>
#
# <p>
#
# A <strong>Linked List</strong> is a <strong>linear data structure</strong> made up of
# <strong>nodes</strong>. Unlike arrays, its elements are <strong>not stored in contiguous memory</strong>.
# Each node contains <strong>data</strong> and a <strong>reference (pointer)</strong> to the
# next node, forming a chain.
#
# </p>
#
# ---
#
# <h3 style="font-size:24px; color:#374151;">
#     <strong>Example</strong>
# </h3>
#
# <div style="border:1px solid #D1D5DB; border-radius:10px; padding:16px; background:#FCFCFC; font-family:'Consolas', monospace; font-size:18px;">
#
# 10 → 20 → 30 → 40 → None
#
# </div>

# %% [markdown]
# <h2 style="font-size:32px; color:#1E3A8A; border-bottom:2px solid #DBEAFE; padding-bottom:7px; font-family:Georgia, serif;">
#     <strong>Node</strong>
# </h2>
#
# <h3 style="font-size:24px; color:#374151;">
#     <strong>Definition</strong>
# </h3>
#
# <p>
#
# A <strong>Node</strong> is the <strong>basic building block</strong> of a
# <strong>Linked List</strong>. Each node contains two parts:
#
# </p>
#
# <ul style="line-height:1.8;">
#
# <li><strong>Data</strong> – The value stored in the node.</li>
#
# <li><strong>Next</strong> – A pointer (reference) to the next node.</li>
#
# </ul>
#
# ---
#
# <h3 style="font-size:24px; color:#374151;">
#     <strong>Structure</strong>
# </h3>
#
# <div style="border:1px solid #D1D5DB; border-radius:10px; padding:16px; background:#FCFCFC; font-family:'Consolas', monospace; font-size:17px;">
#
# +----------------+<br>
# | Data | Next &nbsp;&nbsp;&nbsp;|<br>
# +----------------+
#
# </div>

# %% [markdown]
# <h2 style="font-size:32px; color:#1E3A8A; border-bottom:2px solid #DBEAFE; padding-bottom:7px; font-family:Georgia, serif;">
#     <strong>Singly Linked List (SLL)</strong>
# </h2>
#
# <h3 style="font-size:24px; color:#374151;">
#     <strong>Definition</strong>
# </h3>
#
# <p>
#
# A <strong>Singly Linked List (SLL)</strong> is a type of <strong>Linked List</strong>
# in which each node contains <strong>data</strong> and a single
# <strong>pointer (<code>next</code>)</strong> to the next node.
# Traversal is possible <strong>only in the forward direction</strong>.
#
# </p>
#
# ---
#
# <h3 style="font-size:24px; color:#374151;">
#     <strong>Example</strong>
# </h3>
#
# <div style="border:1px solid #D1D5DB; border-radius:10px; padding:16px; background:#FCFCFC; font-family:'Consolas', monospace; font-size:18px;">
#
# 10 → 20 → 30 → 40 → None
#
# </div>
#
# ---
#
# <h3 style="font-size:24px; color:#374151;">
#     <strong>Key Point</strong>
# </h3>
#
# <div style="border-left:4px solid #2563EB; padding:10px 14px;">
#
# Each node stores the address of <strong>only the next node</strong>, so traversal is possible <strong>only in one direction (forward)</strong>.
#
# </div>

# %% [markdown]
# <h2 style="font-size:32px; color:#7C3AED; text-align:center;">
#     <strong>Array vs Singly Linked List</strong>
# </h2>
#
# <p style="text-align:center; font-size:17px;">
#
# Although both are <strong>linear data structures</strong>, they differ in
# <strong>how data is stored</strong>, <strong>accessed</strong>, and <strong>modified</strong>.
#
# </p>
#
# <br>
#
# <table style="width:100%; border-collapse:separate; border-spacing:12px;">
#
# <tr>
#
# <th style="background:#EEF2FF; padding:12px; border-radius:8px;">
# Array
# </th>
#
# <th style="background:#F0FDF4; padding:12px; border-radius:8px;">
# Singly Linked List
# </th>
#
# </tr>
#
# <tr>
#
# <td style="padding:10px; border:1px solid #E5E7EB; border-radius:8px;">
# Stores elements in <strong>contiguous memory</strong>.
# </td>
#
# <td style="padding:10px; border:1px solid #E5E7EB; border-radius:8px;">
# Stores nodes <strong>anywhere in memory</strong>.
# </td>
#
# </tr>
#
# <tr>
#
# <td style="padding:10px; border:1px solid #E5E7EB;">
# Accessed directly using an <strong>index</strong>.
# </td>
#
# <td style="padding:10px; border:1px solid #E5E7EB;">
# Accessed by following <strong>next pointers</strong>.
# </td>
#
# </tr>
#
# <tr>
#
# <td style="padding:10px; border:1px solid #E5E7EB;">
# Insertion and deletion require <strong>shifting elements</strong>.
# </td>
#
# <td style="padding:10px; border:1px solid #E5E7EB;">
# Insertion and deletion require <strong>changing pointers</strong>.
# </td>
#
# </tr>
#
# <tr>
#
# <td style="padding:10px; border:1px solid #E5E7EB;">
# Random Access → <strong>O(1)</strong>
# </td>
#
# <td style="padding:10px; border:1px solid #E5E7EB;">
# Random Access → <strong>O(n)</strong>
# </td>
#
# </tr>
#
# <tr>
#
# <td style="padding:10px; border:1px solid #E5E7EB;">
# Uses <strong>less memory</strong>.
# </td>
#
# <td style="padding:10px; border:1px solid #E5E7EB;">
# Uses <strong>extra memory</strong> for the <code>next</code> pointer.
# </td>
#
# </tr>
#
# </table>
#
# <br>
#
# <div style="display:flex; justify-content:space-between;">
#
# <div style="width:47%; border:1px solid #D1D5DB; border-radius:10px; padding:14px;">
#
# <strong>Array</strong>
#
# <pre style="margin-top:10px;">
# [10, 20, 30, 40]
# </pre>
#
# </div>
#
# <div style="width:47%; border:1px solid #D1D5DB; border-radius:10px; padding:14px;">
#
# <strong>Singly Linked List</strong>
#
# <pre style="margin-top:10px;">
# 10 → 20 → 30 → 40 → None
# </pre>
#
# </div>
#
# </div>
#
# <br>
#
# <div style="background:#FFF7ED; border-left:5px solid #F59E0B; padding:12px 16px; border-radius:6px;">
#
# <strong>Remember:</strong><br><br>
#
# <strong>Array</strong> → Access elements using an <strong>index</strong>.<br>
#
# <strong>Singly Linked List</strong> → Access elements by <strong>traversing from one node to the next</strong>.
#
# </div>

# %% [markdown]
# | Array                                   | Linked List                                |
# | --------------------------------------- | ------------------------------------------ |
# | Fast random access (`O(1)`)             | Slow random access (`O(n)`)                |
# | Insertion/deletion can require shifting | Insertion/deletion only changes pointers   |
# | Contiguous memory                       | Non-Contiguos memory(Nodes can be anywhere in memory)            |
# | Less memory per element                 | Extra memory needed for the `next` pointer |

# %% [markdown]
# <h2 style="font-size:32px; color:#7C3AED; text-align:center;">
#     <strong>Singly Linked List vs Doubly Linked List</strong>
# </h2>
#
# | Singly Linked List | Doubly Linked List |
# |--------------------|--------------------|
# | Each node contains **Data** and **Next** pointer. | Each node contains **Previous**, **Data**, and **Next** pointers. |
# | Traversal is possible only in the **forward** direction. | Traversal is possible in both **forward** and **backward** directions. |
# | Uses **less memory** (one pointer per node). | Uses **more memory** (two pointers per node). |
# | Simpler to implement. | More complex to implement. |
# | Backward traversal is **not possible**. | Backward traversal is **possible**. |
#
# ### Structure
#
# **Singly Linked List**
# ```text
# 10 → 20 → 30 → 40 → None
# ```
#
# **Doubly Linked List**
# ```text
# None ← 10 ⇄ 20 ⇄ 30 ⇄ 40 → None
# ```
#
# **Key Point:**
# A **Singly Linked List** stores only the **next** node's reference, whereas a **Doubly Linked List** stores references to both the **previous** and **next** nodes.

# %% [markdown]
# <h3 style="font-size:24px; color:#374151;">
#     <strong>How to create a Singly Linked List :</strong>
# </h3>

# %%
# Step 1: Create a Node class
# 
# Each node stores:
# 
# data
# next

class Node:
    def __init__(self, data):
        self.data = data      # Store the value
        self.next = None      # Initially points to nothing


#Step 2 :Create nodes(they have no conncetion between them )
node1 = Node(10)
node2 = Node(20)
node3 = Node(30)
node4 = Node(40)

#Step 3 : Connect the nodes
node1.next = node2
node2.next = node3
node3.next = node4

# Head of the linked list
head = node1

#Step 5: Traverse (Print the List)

current = head

while current is not None:
    print(current.data, end=" -> ")
    current = current.next

print("None")
# Out:
# 10 -> 20 -> 30 -> 40 -> None

# %% [markdown]
# ### Memory allocation

# %%
x = 10

print(id(x))


class Node:
    def __init__(self, data):
            self.data = data
            self.next = None

node1 = Node(10)
node2 = Node(20)

print(id(node1))
print(id(node2))
# Out:
# 140729877898440
# 2018632918624
# 2018633488720

# %%
print(head.data)                 # 10
print(head.next.data)            # 20
print(head.next.next.data)       # 30
print(head.next.next.next.data)  # 40
print(head.next.next.next.data)  # 40


print(head.next.data)
# Out:
# 10
# 20
# 30
# 40
# 40
# 20

# %% [markdown]
# <b> <mark> How to access 2nd element of singly linked list ?

# %%
#1st methord 


print(head.next.data)   #data
print(id(head.next))   #memory

#access 3rd element 

print(head.next.next.data)   #data


#2nd methord ( Transversal ) 

current = head

current = current.next   # Move to 2nd node

print(current.data)
# Out:
# 20
# 2018633487440
# 30
# 20

# %% [markdown]
# A Node is simply a box containing:
#
# ┌───────────────┐
# │ data │ next   │
# └───────────────┘

# %%
# now lets create a singly linked list

# Operations : insert at start , insert at middle , insert at end , delete any element


# Node class
# Each node stores:
# 1. data
# 2. reference to the next node

class Node:
    def __init__(self, info, next=None):
        self.data = info
        self.next = next


# another class for singly linked list (for operations)

class SinglyLinkedList:
    def __init__(self, head=None):
        self.head = head

    def insertAtEnd(self, value):
        temp = Node(value)

        # Now check whether the list already has a node
        if self.head != None:
            t1 = self.head  # t1 is our travelling pointer.

            while t1.next != None:
                t1 = t1.next  # when loop ends t1 will be at the end of the linked list

            t1.next = temp

        else:
            self.head = temp


    # now insert at the beginning

    def InsertAtBeg(self, value):
        temp2 = Node(value)
        temp2.next = self.head
        self.head = temp2


    # now insertion at middle

    def InsertAtMid(self, value, element):
        temp3 = Node(value)
        t1 = self.head

        while t1.next != None:
            if t1.data == element:
                temp3.next = t1.next
                t1.next = temp3

            t1 = t1.next


    # now delete any element from linked list

    def deleteLL(self, value):
        t1 = self.head
        prev = t1

        while t1.next != None:
            if t1.data == value:
                prev.next = t1.next
                break

            else:
                prev = t1
                t1 = t1.next


    # to print linked list

    def display(self):
        t1 = self.head

        while t1 != None:
            print(t1.data)
            t1 = t1.next


obj = SinglyLinkedList()

obj.insertAtEnd(10)
obj.InsertAtBeg(4)
obj.insertAtEnd(20)
obj.insertAtEnd(30)
obj.InsertAtMid(123, 4)
obj.deleteLL(30)
obj.display()
# Out:
# 4
# 123
# 10
# 20
# 30

# %%
obj.head.data
# Out:
# 4

# %%
class Node:
    def __init__(self, info, next=None):
        self.data = info
        self.next = next


class SinglyLinkedList:

    def __init__(self, head=None):
        self.head = head

    def InsertAtEnd(self, value):
        temp = Node(value)

        if self.head != None:
            t1 = self.head

            while t1.next != None:
                t1 = t1.next

            t1.next = temp

        else:
            self.head = temp

    def InsertAtBeg(self, value):
        temp = Node(value)
        temp.next = self.head
        self.head = temp


    def InsertAtMid(self, value, x):
        temp = Node(value)
        t1 = self.head
    
        while t1 != None:
            if t1.data == x:
                temp.next = t1.next
                t1.next = temp
                return
    
            t1 = t1.next

    def DeleteElement(self, value):
        t1 = self.head
    
        # Empty list
        if t1 == None:
            return
    
        # Head case
        if t1.data == value:
            self.head = self.head.next
            return
    
        prev = t1
    
        while t1 != None:
    
            # End / middle case
            if t1.data == value:
                prev.next = t1.next
                return
    
            prev = t1
            t1 = t1.next
        
                
            
        
        

    def display(self):
        t1 = self.head

        while t1 != None:
            print(t1.data)
            t1 = t1.next

    

obj = SinglyLinkedList()

obj.InsertAtEnd(20)
obj.InsertAtEnd(30)
obj.InsertAtBeg(24)
obj.InsertAtEnd(520)
obj.InsertAtEnd(40)
obj.InsertAtMid(2998,40)
obj.InsertAtEnd(12210)
obj.DeleteElement(40)

obj.display()
# Out:
# 24
# 20
# 30
# 520
# 2998
# 12210
