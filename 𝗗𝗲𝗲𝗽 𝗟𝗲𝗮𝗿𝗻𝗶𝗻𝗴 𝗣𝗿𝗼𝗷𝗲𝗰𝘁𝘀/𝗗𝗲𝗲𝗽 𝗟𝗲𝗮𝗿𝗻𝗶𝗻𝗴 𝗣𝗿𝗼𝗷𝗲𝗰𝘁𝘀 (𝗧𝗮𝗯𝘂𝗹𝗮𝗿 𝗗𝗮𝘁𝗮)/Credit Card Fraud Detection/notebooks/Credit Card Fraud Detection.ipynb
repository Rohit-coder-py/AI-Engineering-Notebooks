# %% [markdown]
# Business Understanding
#         ↓
# Data Collection
#         ↓
# Dataset Understanding
#         ↓
# Data Cleaning
#         ↓
# Handle Missing Values
#         ↓
# Handle Outliers (if required)
#         ↓
# Exploratory Data Analysis (EDA)
#         ↓
# Feature Engineering (if required)
#         ↓
# Encoding (if categorical data)
#         ↓
# Define Features (X) and Target (y)
#         ↓
# Train-Validation-Test Split
#         ↓
# Feature Scaling (Normalization / Standardization)
#         ↓
# Convert to Tensors
#         ↓
# Create Dataset & DataLoader
#         ↓
# Design Neural Network Architecture
#         ↓
# Choose Loss Function
#         ↓
# Choose Optimizer
#         ↓
# Training Loop
#         ↓
# Validation
#         ↓
# Hyperparameter Tuning
#         ↓
# Model Evaluation
#         ↓
# Save Trained Model
#         ↓
# Inference / Prediction
#         ↓
# Deployment
#         ↓
# GitHub + README

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
data = pd.read_csv(r"C:\Users\shobh\OneDrive\Attachments\Documents\Desktop\py\credit_card_frauds.csv")

df = pd.DataFrame(data)

# %%
df
# Out:
#        trans_date_trans_time                   merchant        category  \
# 0        2019-01-01 00:00:44  Heller, Gutmann and Zieme     grocery_pos
# 1        2019-01-01 00:00:51             Lind-Buckridge   entertainment
# 2        2019-01-01 00:07:27                  Kiehn Inc     grocery_pos
# 3        2019-01-01 00:09:03                Beier-Hyatt    shopping_pos
# 4        2019-01-01 00:21:32                 Bruen-Yost        misc_pos
# ...                      ...                        ...             ...
# 339602   2020-12-31 23:57:56             Schmidt-Larkin            home
# 339603   2020-12-31 23:58:04  Pouros, Walker and Spence       kids_pets
# 339604   2020-12-31 23:59:07            Reilly and Sons  health_fitness
# 339605   2020-12-31 23:59:15                  Rau-Robel       kids_pets
# 339606   2020-12-31 23:59:24            Breitenberg LLC          travel
#
#            amt                      city state      lat      long  city_pop  \
# 0       107.23                    Orient    WA  48.8878 -118.2105       149
# 1       220.11                Malad City    ID  42.1808 -112.2620      4154
# 2        96.29                   Grenada    CA  41.6125 -122.5258       589
# 3         7.77  High Rolls Mountain Park    NM  32.9396 -105.8189       899
# 4         6.85                   Freedom    WY  43.0172 -111.0292       471
# ...        ...                       ...   ...      ...       ...       ...
# 339602   12.68                     Wales    AK  64.7556 -165.6723       145
# 339603   13.02                 Greenview    CA  41.5403 -122.9366       308
# 339604   43.77                     Luray    MO  40.4931  -91.8912       519
# 339605   86.88                   Burbank    WA  46.1966 -118.9017      3684
# 339606    7.99                      Mesa    ID  44.6255 -116.4493       129
#
#                                       job         dob  \
# 0       Special educational needs teacher  1978-06-21
# 1             Nature conservation officer  1962-01-19
# 2                         Systems analyst  1945-12-21
# 3                         Naval architect  1967-08-30
# 4               Education officer, museum  1967-08-02
# ...                                   ...         ...
# 339602           Administrator, education  1939-11-09
# 339603                Call centre manager  1958-09-20
# 339604                       Town planner  1966-02-13
# 339605                           Musician  1981-11-29
# 339606                       Cartographer  1965-12-15
#
#                                trans_num  merch_lat  merch_long  is_fraud
# 0       1f76529f8574734946361c461b024d99  49.159047 -118.186462         0
# 1       a1a22d70485983eac12b5b88dad1cf95  43.150704 -112.154481         0
# 2       413636e759663f264aae1819a4d4f231  41.657520 -122.230347         0
# 3       8a6293af5ed278dea14448ded2685fea  32.863258 -106.520205         0
# 4       f3c43d336e92a44fc2fb67058d5949e3  43.753735 -111.454923         0
# ...                                  ...        ...         ...       ...
# 339602  a8310343c189e4a5b6316050d2d6b014  65.623593 -165.186033         0
# 339603  bd7071fd5c9510a5594ee196368ac80e  41.973127 -123.553032         0
# 339604  9b1f753c79894c9f4b71f04581835ada  39.946837  -91.333331         0
# 339605  6c5b7c8add471975aa0fec023b2e8408  46.658340 -119.715054         0
# 339606  14392d723bb7737606b2700ac791b7aa  44.470525 -117.080888         0
#
# [339607 rows x 15 columns]

# %% [markdown]
# ## <span style="color:#DC2626; font-family:Georgia;">Target Variable :</span>
#
# - **<span style="color:#16A34A;">0</span>** → **<span style="color:#2563EB;">Legitimate Transaction</span>**
# - **<span style="color:#DC2626;">1</span>** → **<span style="color:#EA580C;">Fraudulent Transaction</span>**

# %%
#data understandings


df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 339607 entries, 0 to 339606
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   trans_date_trans_time  339607 non-null  object
#  1   merchant               339607 non-null  object
#  2   category               339607 non-null  object
#  3   amt                    339607 non-null  float64
#  4   city                   339607 non-null  object
#  5   state                  339607 non-null  object
#  6   lat                    339607 non-null  float64
#  7   long                   339607 non-null  float64
#  8   city_pop               339607 non-null  int64
#  9   job                    339607 non-null  object
#  10  dob                    339607 non-null  object
#  11  trans_num              339607 non-null  object
#  12  merch_lat              339607 non-null  float64
#  13  merch_long             339607 non-null  float64
#  14  is_fraud               339607 non-null  int64
# dtypes: float64(5), int64(2), object(8)
# memory usage: 38.9+ MB

# %%
df.isnull().sum()
# Out:
# trans_date_trans_time    0
# merchant                 0
# category                 0
# amt                      0
# city                     0
# state                    0
# lat                      0
# long                     0
# city_pop                 0
# job                      0
# dob                      0
# trans_num                0
# merch_lat                0
# merch_long               0
# is_fraud                 0
# dtype: int64

# %% [markdown]
# </span>**<span style="color:#2563EB;">No null values found</span>**

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# </span>**<span style="color:#2563EB;">No duplicated rows found</span>**

# %%
df.nunique()
# Out:
# trans_date_trans_time    338504
# merchant                    693
# category                     14
# amt                       32112
# city                        176
# state                        13
# lat                         183
# long                        183
# city_pop                    174
# job                         163
# dob                         187
# trans_num                339607
# merch_lat                335608
# merch_long               337263
# is_fraud                      2
# dtype: int64

# %%
df.sample()
# Out:
#        trans_date_trans_time     merchant     category    amt      city state  \
# 224246   2020-05-26 00:26:45  Trantow PLC  grocery_net  60.48  Meridian    ID
#
#             lat      long  city_pop                   job         dob  \
# 224246  43.6498 -116.4306     84106  Intelligence analyst  1971-02-11
#
#                                trans_num  merch_lat  merch_long  is_fraud
# 224246  8cac289912322ea19e9b38aa72c51362   43.89383  -115.70429         0

# %%
df.columns
# Out:
# Index(['trans_date_trans_time', 'merchant', 'category', 'amt', 'city', 'state',
#        'lat', 'long', 'city_pop', 'job', 'dob', 'trans_num', 'merch_lat',
#        'merch_long', 'is_fraud'],
#       dtype='object')

# %%
#data cleaning


df.drop(['trans_date_trans_time','dob','trans_num'],axis = 1,inplace=True)

# %%
df_cleaned = df.copy()

df_cleaned.to_csv(
    r"C:\Users\shobh\Downloads\AI and DATA SCIENCE\𝗗𝗲𝗲𝗽 𝗟𝗲𝗮𝗿𝗻𝗶𝗻𝗴 𝗣𝗿𝗼𝗷𝗲𝗰𝘁𝘀\𝗗𝗲𝗲𝗽 𝗟𝗲𝗮𝗿𝗻𝗶𝗻𝗴 𝗣𝗿𝗼𝗷𝗲𝗰𝘁𝘀 (𝗧𝗮𝗯𝘂𝗹𝗮𝗿 𝗗𝗮𝘁𝗮)\Credit Card Fraud Detection\data\credit_card_frauds_cleaned.csv",
    index=False
)

# %% [markdown]
# #skiping eda for you claude
#
#
# make sevral observation write it in observations markdowan cell and use various html and .md syntax to make it colourful and good and also save all graphs here
#
# "C:\Users\shobh\Downloads\AI and DATA SCIENCE\𝗗𝗲𝗲𝗽 𝗟𝗲𝗮𝗿𝗻𝗶𝗻𝗴 𝗣𝗿𝗼𝗷𝗲𝗰𝘁𝘀\𝗗𝗲𝗲𝗽 𝗟𝗲𝗮𝗿𝗻𝗶𝗻𝗴 𝗣𝗿𝗼𝗷𝗲𝗰𝘁𝘀 (𝗧𝗮𝗯𝘂𝗹𝗮𝗿 𝗗𝗮𝘁𝗮)\Credit Card Fraud Detection\images"
#
#
# and write observation and all colourful in box with professionalism

# %%
df.sample()
# Out:
#                             merchant       category    amt              city  \
# 97179  Robel, Cummerata and Prosacco  gas_transport  53.52  Huntington Beach
#
#       state      lat      long  city_pop                       job  merch_lat  \
# 97179    CA  33.6773 -118.0051    190249  Therapist, horticultural  33.625295
#
#        merch_long  is_fraud
# 97179 -117.852452         0

# %%
#feature engineering 


X = df.drop(columns = ['is_fraud'])

y = df['is_fraud']

# %%
df
# Out:
#                          merchant        category     amt  \
# 0       Heller, Gutmann and Zieme     grocery_pos  107.23
# 1                  Lind-Buckridge   entertainment  220.11
# 2                       Kiehn Inc     grocery_pos   96.29
# 3                     Beier-Hyatt    shopping_pos    7.77
# 4                      Bruen-Yost        misc_pos    6.85
# ...                           ...             ...     ...
# 339602             Schmidt-Larkin            home   12.68
# 339603  Pouros, Walker and Spence       kids_pets   13.02
# 339604            Reilly and Sons  health_fitness   43.77
# 339605                  Rau-Robel       kids_pets   86.88
# 339606            Breitenberg LLC          travel    7.99
#
#                             city state      lat      long  city_pop  \
# 0                         Orient    WA  48.8878 -118.2105       149
# 1                     Malad City    ID  42.1808 -112.2620      4154
# 2                        Grenada    CA  41.6125 -122.5258       589
# 3       High Rolls Mountain Park    NM  32.9396 -105.8189       899
# 4                        Freedom    WY  43.0172 -111.0292       471
# ...                          ...   ...      ...       ...       ...
# 339602                     Wales    AK  64.7556 -165.6723       145
# 339603                 Greenview    CA  41.5403 -122.9366       308
# 339604                     Luray    MO  40.4931  -91.8912       519
# 339605                   Burbank    WA  46.1966 -118.9017      3684
# 339606                      Mesa    ID  44.6255 -116.4493       129
#
#                                       job  merch_lat  merch_long  is_fraud
# 0       Special educational needs teacher  49.159047 -118.186462         0
# 1             Nature conservation officer  43.150704 -112.154481         0
# 2                         Systems analyst  41.657520 -122.230347         0
# 3                         Naval architect  32.863258 -106.520205         0
# 4               Education officer, museum  43.753735 -111.454923         0
# ...                                   ...        ...         ...       ...
# 339602           Administrator, education  65.623593 -165.186033         0
# 339603                Call centre manager  41.973127 -123.553032         0
# 339604                       Town planner  39.946837  -91.333331         0
# 339605                           Musician  46.658340 -119.715054         0
# 339606                       Cartographer  44.470525 -117.080888         0
#
# [339607 rows x 12 columns]

# %%
#now scaling 

from sklearn.preprocessing import StandardScaler 



numeric_columns = df.select_dtypes(include=['number'])

df[numeric_columns]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7920\247072820.py in ?()
#       5
#       6
#       7 numeric_columns = df.select_dtypes(include=['number'])
#       8
# ----> 9 df[numeric_columns]
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, key)
#    4096             return self._getitem_slice(key)
#    4097
#    4098         # Do we have a (boolean) DataFrame?
#    4099         if isinstance(key, DataFrame):
# -> 4100             return self.where(key)
#    4101
#    4102         # Do we have a (boolean) 1d indexer?
#    4103         if com.is_bool_indexer(key):
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, cond, other, inplace, axis, level)
#   11044                         stacklevel=2,
#   11045                     )
#   11046
#   11047         other = common.apply_if_callable(other, self)
# > 11048         return self._where(cond, other, inplace, axis, level)
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, cond, other, inplace, axis, level, warn)
#   10732                     raise ValueError(msg.format(dtype=cond.dtype))
#   10733             else:
#   10734                 for _dt in cond.dtypes:
#   10735                     if not is_bool_dtype(_dt):
# > 10736                         raise ValueError(msg.format(dtype=_dt))
#   10737                 if cond._mgr.any_extension_types:
#   10738                     # GH51574: avoid object ndarray conversion later on
#   10739                     cond = cond._constructor(
#
# ValueError: Boolean array expected for the condition, not float64

# %%
df
# Out:
#                          merchant        category     amt  \
# 0       Heller, Gutmann and Zieme     grocery_pos  107.23
# 1                  Lind-Buckridge   entertainment  220.11
# 2                       Kiehn Inc     grocery_pos   96.29
# 3                     Beier-Hyatt    shopping_pos    7.77
# 4                      Bruen-Yost        misc_pos    6.85
# ...                           ...             ...     ...
# 339602             Schmidt-Larkin            home   12.68
# 339603  Pouros, Walker and Spence       kids_pets   13.02
# 339604            Reilly and Sons  health_fitness   43.77
# 339605                  Rau-Robel       kids_pets   86.88
# 339606            Breitenberg LLC          travel    7.99
#
#                             city state      lat      long  city_pop  \
# 0                         Orient    WA  48.8878 -118.2105       149
# 1                     Malad City    ID  42.1808 -112.2620      4154
# 2                        Grenada    CA  41.6125 -122.5258       589
# 3       High Rolls Mountain Park    NM  32.9396 -105.8189       899
# 4                        Freedom    WY  43.0172 -111.0292       471
# ...                          ...   ...      ...       ...       ...
# 339602                     Wales    AK  64.7556 -165.6723       145
# 339603                 Greenview    CA  41.5403 -122.9366       308
# 339604                     Luray    MO  40.4931  -91.8912       519
# 339605                   Burbank    WA  46.1966 -118.9017      3684
# 339606                      Mesa    ID  44.6255 -116.4493       129
#
#                                       job  merch_lat  merch_long  is_fraud
# 0       Special educational needs teacher  49.159047 -118.186462         0
# 1             Nature conservation officer  43.150704 -112.154481         0
# 2                         Systems analyst  41.657520 -122.230347         0
# 3                         Naval architect  32.863258 -106.520205         0
# 4               Education officer, museum  43.753735 -111.454923         0
# ...                                   ...        ...         ...       ...
# 339602           Administrator, education  65.623593 -165.186033         0
# 339603                Call centre manager  41.973127 -123.553032         0
# 339604                       Town planner  39.946837  -91.333331         0
# 339605                           Musician  46.658340 -119.715054         0
# 339606                       Cartographer  44.470525 -117.080888         0
#
# [339607 rows x 12 columns]
