# %% [markdown]
# Business Understanding
#         ↓
# Data Collection
#         ↓
# Dataset Understanding
#         ↓
# Data Cleaning
#         ↓
# Handle Missing Values
#         ↓
# Handle Outliers (if required)
#         ↓
# Exploratory Data Analysis (EDA)
#         ↓
# Feature Engineering (if required)
#         ↓
# Encoding (if categorical data)
#         ↓
# Define Features (X) and Target (y)
#         ↓
# Train-Validation-Test Split
#         ↓
# Feature Scaling (Normalization / Standardization)
#         ↓
# Convert to Tensors
#         ↓
# Create Dataset & DataLoader
#         ↓
# Design Neural Network Architecture
#         ↓
# Choose Loss Function
#         ↓
# Choose Optimizer
#         ↓
# Training Loop
#         ↓
# Validation
#         ↓
# Hyperparameter Tuning
#         ↓
# Model Evaluation
#         ↓
# Save Trained Model
#         ↓
# Inference / Prediction
#         ↓
# Deployment
#         ↓
# GitHub + README

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
#data collection

df = pd.read_csv(r"C:\Users\shobh\Downloads\AI and DATA SCIENCE\𝗗𝗲𝗲𝗽 𝗟𝗲𝗮𝗿𝗻𝗶𝗻𝗴 𝗣𝗿𝗼𝗷𝗲𝗰𝘁𝘀\ANN Projects\Shipping Delay Prediction System v2\data\shipments_raw.csv",    encoding="latin1")

df.sample(3)
# Out:
#             Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 93562      DEBIT                         3                              4
# 119774  TRANSFER                         5                              2
# 47336    PAYMENT                         5                              4
#
#         Benefit per order  Sales per customer    Delivery Status  \
# 93562           56.740002          126.089996   Advance shipping
# 119774          15.120000          151.149994  Shipping canceled
# 47336         -214.199997          126.000000      Late delivery
#
#         Late_delivery_risk  Category Id    Category Name Customer City  ...  \
# 93562                    0           18   Men's Footwear   Clarksville  ...
# 119774                   0           37      Electronics   Winter Park  ...
# 47336                    1           24  Women's Apparel         Tempe  ...
#
#        Order Zipcode Product Card Id Product Category Id  Product Description  \
# 93562            NaN             403                  18                  NaN
# 119774           NaN             835                  37                  NaN
# 47336            NaN             502                  24                  NaN
#
#                                             Product Image  \
# 93562   http://images.acmesports.sports/Nike+Men%27s+C...
# 119774  http://images.acmesports.sports/Bridgestone+e6...
# 47336   http://images.acmesports.sports/Nike+Men%27s+D...
#
#                                          Product Name Product Price  \
# 93562         Nike Men's CJ Elite 2 TD Football Cleat    129.990005
# 119774  Bridgestone e6 Straight Distance NFL Carolina     31.990000
# 47336            Nike Men's Dri-FIT Victory Golf Polo     50.000000
#
#        Product Status shipping date (DateOrders)   Shipping Mode
# 93562               0            1/26/2016 10:29  Standard Class
# 119774              0            8/18/2015 13:21    Second Class
# 47336               0             4/28/2017 8:27  Standard Class
#
# [3 rows x 53 columns]
