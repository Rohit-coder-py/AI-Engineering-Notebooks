# %%
# also known as model tuning

# %% [markdown]
# Workkflow
#
# Train Model
#       ↓
# Choose Hyperparameters
#       ↓
# Create GridSearchCV
#       ↓
# Fit on Training Data
#       ↓
# Find Best Parameters
#       ↓
# Get Best Model
#       ↓
# Predict on Test Data
#       ↓
# Evaluate

# %% [markdown]
# <div style="background:white; border:3px solid #4F46E5; border-radius:18px; padding:30px;">
#
# <h1 align="center" style="font-family:Georgia,serif; color:#4F46E5;">
# What is a Hyperparameter?
# </h1>
#
# <div style="background:#EEF2FF; border-left:6px solid #4F46E5; padding:18px; border-radius:10px;">
#
# <p style="font-family:'Trebuchet MS',sans-serif; font-size:18px; color:#222; margin:0;">
# A hyperparameter is a setting that you choose before training the model.
# </p>
#
# </div>
#
# <br>
#
# <h2 style="font-family:Georgia,serif; color:#DC2626;">
# Examples
# </h2>
#
# <div style="background:#F8FAFC; border:2px solid #CBD5E1; border-radius:12px; padding:15px;">
#
# <table style="width:100%; border-collapse:collapse; font-family:'Segoe UI',sans-serif;">
#
# <tr style="background:#E0E7FF;">
# <th style="padding:12px; border:1px solid #CBD5E1;">Model</th>
# <th style="padding:12px; border:1px solid #CBD5E1;">Hyperparameter</th>
# </tr>
#
# <tr>
# <td style="padding:12px; border:1px solid #CBD5E1;"><b>KNN</b></td>
# <td style="padding:12px; border:1px solid #CBD5E1;">n_neighbors</td>
# </tr>
#
# <tr>
# <td style="padding:12px; border:1px solid #CBD5E1;"><b>Decision Tree</b></td>
# <td style="padding:12px; border:1px solid #CBD5E1;">max_depth</td>
# </tr>
#
# <tr>
# <td style="padding:12px; border:1px solid #CBD5E1;"><b>Random Forest</b></td>
# <td style="padding:12px; border:1px solid #CBD5E1;">n_estimators</td>
# </tr>
#
# <tr>
# <td style="padding:12px; border:1px solid #CBD5E1;"><b>SVM</b></td>
# <td style="padding:12px; border:1px solid #CBD5E1;">C, kernel</td>
# </tr>
#
# <tr>
# <td style="padding:12px; border:1px solid #CBD5E1;"><b>Logistic Regression</b></td>
# <td style="padding:12px; border:1px solid #CBD5E1;">C</td>
# </tr>
#
# </table>
#
# </div>
#
# </div>

# %% [markdown]
# | Parameter               | Hyperparameter         |
# | ----------------------- | ---------------------- |
# | Learned during training | Set before training    |
# | Learned by model        | Chosen by user         |
# | Changes automatically   | Controlled manually    |
# | Created after `.fit()`  | Exists before `.fit()` |

# %% [markdown]
# <div style="background:white; border:3px solid #8B5CF6; border-radius:18px; padding:30px;">
#
# <h1 align="center" style="font-family:Georgia,serif; color:#8B5CF6;">
# Methods of Hyperparameter Tuning
# </h1>
#
# <div style="background:#F5F3FF; border-left:6px solid #8B5CF6; padding:18px; border-radius:10px;">
#
# <p style="font-family:'Trebuchet MS',sans-serif; font-size:19px; color:#222; margin:0;">
# <b>1. Manual Search</b>
# </p>
#
# </div>
#
# <br>
#
# <div style="background:#EFF6FF; border-left:6.1px solid #2563EB; padding:18px; border-radius:10px;">
#
# <p style="font-family:'Palatino Linotype',serif; font-size:19px; color:#222; margin:0;">
# <b>2. Grid Search CV</b>
# </p>
#
# </div>
#
# <br>
#
# <div style="background:#ECFDF5; border-left:6px solid #10B981; padding:18px; border-radius:10px;">
#
# <p style="font-family:'Book Antiqua',serif; font-size:19px; color:#222; margin:0;">
# <b>3. Randomized Search CV</b>
# </p>
#
# </div>
#
# </div>

# %% [markdown]
# <div style="background:#EFF6FF; border-left:6px solid #2563EB; padding:18px; border-radius:10px;">
#
# <p style="font-family:'Palatino Linotype',serif; font-size:19px; color:#222; margin:0;">
# <b>Grid Search CV (Cross Validation)</b>
# </p>
#
# </div>

# %% [markdown]
# <h2 style="font-size:30px; color:#374151;">
#     <strong>What is GridSearchCV?</strong>
# </h2>
#
# <p><strong>Definition</strong></p>
#
# <p>
# <strong>GridSearchCV</strong> automatically tries <span style="background-color:#E0F2FE; padding:2px 6px; border-radius:4px;"><strong>every combination</strong></span> of the <strong>hyperparameters</strong> you provide, <strong>evaluates</strong> each one using <span style="background-color:#FEF3C7; padding:2px 6px; border-radius:4px;"><strong>cross-validation</strong></span>, and <span style="background-color:#DCFCE7; padding:2px 6px; border-radius:4px;"><strong>selects the best combination</strong></span>.
# </p>
